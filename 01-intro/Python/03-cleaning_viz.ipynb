# %% [markdown]
# # Cleaning data in python
# - we start with the same data and perform the same cleaning steps

# %%
import pandas as pd

# %%
name = [
  'Wardruna',
  'Skinflower',
  'Behemoth',
  'Konvent',
  'Ultha',
  'Chthonic',
  'Jinjer'
]
country = [
  'Norway',
  'Netherlands',
  'Poland',
  'Denmark',
  'Germany',
  'Taiwan',
  'Ukraine'
]
albums = [5, None, 12, 2, 4, 11, 4]
singles_ep = [3, None, 12, 0, 4, 14, 3]
splits = [1, None, 1, 0, 3, 2, None]
formed = [2003, None, 1991, 2015, 2014, 1995, 2009]

#bands = 

#bands <- dplyr::tibble(name, country, albums, singles_ep, splits, formed)
# calculate age and productivity
#bands <- bands %>% 
#  mutate(age = 2023 - formed) %>% 
#  mutate(productivity = albums / age)

# %%
bands = pd.DataFrame(list(zip(
    name, country, albums, singles_ep, splits, formed
)), columns = ['name', 'country', 'albums', 'singles_ep', 'splits', 'formed'])

# %%
# calculate productivity
bands['age'] = 2023 - bands['formed']
bands['productivity'] = bands['albums'] / bands['age']

# %%
bands.head()
# Out:
#          name      country  albums  singles_ep  splits  formed   age  \
# 0    Wardruna       Norway     5.0         3.0     1.0  2003.0  20.0
# 1  Skinflower  Netherlands     NaN         NaN     NaN     NaN   NaN
# 2    Behemoth       Poland    12.0        12.0     1.0  1991.0  32.0
# 3     Konvent      Denmark     2.0         0.0     0.0  2015.0   8.0
# 4       Ultha      Germany     4.0         4.0     3.0  2014.0   9.0
#
#    productivity
# 0      0.250000
# 1           NaN
# 2      0.375000
# 3      0.250000
# 4      0.444444

# %%
albums = pd.read_csv('albums.csv')

# %%
albums.head()
# Out:
#        band                         name         kind  published  n_reviews  \
# 0  Wardruna  Runaljod - gap var Ginnunga  Full-length       2009        6.0
# 1  Wardruna     The Pagan Herald No. III        Split       2009        NaN
# 2  Wardruna                         Fehu       Single       2013        NaN
# 3  Wardruna         Runaljod - Yggdrasil  Full-length       2013        4.0
# 4  Wardruna                 Loyndomsriss       Single       2014        NaN
#
#    r_percent
# 0       98.0
# 1        NaN
# 2        NaN
# 3       92.0
# 4        NaN

# %%
# merging the dataframes:
both = pd.merge(left=bands, right=albums, left_on='name', right_on='band', how='left')

# %%
both.drop(['band', 'n_reviews', 'r_percent'], axis=1, inplace=True)

# %%
both.rename({'name_x':'band', 'name_y':'album'}, inplace=True, axis=1)

# %%
both.head()
# Out:
#        band country  albums  singles_ep  splits  formed   age  productivity  \
# 0  Wardruna  Norway     5.0         3.0     1.0  2003.0  20.0          0.25
# 1  Wardruna  Norway     5.0         3.0     1.0  2003.0  20.0          0.25
# 2  Wardruna  Norway     5.0         3.0     1.0  2003.0  20.0          0.25
# 3  Wardruna  Norway     5.0         3.0     1.0  2003.0  20.0          0.25
# 4  Wardruna  Norway     5.0         3.0     1.0  2003.0  20.0          0.25
#
#                          album         kind  published
# 0  Runaljod - gap var Ginnunga  Full-length     2009.0
# 1     The Pagan Herald No. III        Split     2009.0
# 2                         Fehu       Single     2013.0
# 3         Runaljod - Yggdrasil  Full-length     2013.0
# 4                 Loyndomsriss       Single     2014.0

# %%
# remove rows with missing values
both = both.dropna()

# %% [markdown]
# # Visualization with [altair](https://altair-viz.github.io/index.html)
# - has to be installed!
# - imported as `import altair as alt`
# - quite similar in chaining operations to ggplot
# - the base 'recipe' is as follows:
#   - `alt.Chart(data)`-> data to be used
#   - `.mark()` -> chart style (e.g. `mark_bar()`, `mark_line()` etc.)
#   - `.encode(x=..., y=..., options)` -> what to encode from the data

# %%
# !pip install altair
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: altair in /usr/local/lib/python3.10/dist-packages (4.2.2)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair) (0.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from altair) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair) (4.3.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from altair) (1.22.4)
# Requirement already satisfied: pandas>=0.18 in /usr/local/lib/python3.10/dist-packages (from altair) (1.5.3)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair) (0.12.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair) (0.19.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.18->altair) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.18->altair) (2022.7.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->altair) (2.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=0.18->altair) (1.16.0)

# %%
import altair as alt

# %%
# simple scatter plot
alt.Chart(bands).mark_point().encode(
    x='formed',
    y='productivity',
)
# axis normally start at zero
# Out:
# alt.Chart(...)

# %%
# restrict the x axis to a specific domain
alt.Chart(bands).mark_point().encode(
    x=alt.X(
        'formed',
        scale=alt.Scale(domain=[1990, 2016])
        ),
    y='productivity',
)
# Out:
# alt.Chart(...)

# %%
# the cumulative count is a bit more involved than with ggplot2!

# %%
ot = both.groupby(['band', 'published']).count().reset_index()[['band', 'published', 'albums']]

# %%
csums=both.groupby(['band', 'published']).count().reset_index().groupby('band').cumsum()['albums']

# %%
ot['csums'] = csums

# %%
ot.head()
# Out:
#        band  published  albums  csums
# 0  Behemoth     1995.0       2      2
# 1  Behemoth     1996.0       1      3
# 2  Behemoth     1997.0       2      5
# 3  Behemoth     1998.0       1      6
# 4  Behemoth     1999.0       1      7

# %%
alt.Chart(
    ot
).mark_line().encode(
    x= alt.X('published', scale=alt.Scale(domain=[1990, 2023])),
    y='csums',
    color='band'
)
# Out:
# alt.Chart(...)
